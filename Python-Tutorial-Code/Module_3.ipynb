# %%
import pandas

# %%
import pandas as pandas

# %%
filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"

# %%
child_id = pandas.read_csv (filepath)
#type (child_id)
#child_id.info
#child_id.head
child_id.tail
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 child_id = pandas.read_csv (filepath)
#       2 #type (child_id)
#       3 #child_id.info
#       4 #child_id.head
#       5 child_id.tail
#
# NameError: name 'pandas' is not defined

# %%
child_id = pandas.read_csv (filepath)

child_id["PersonBirthDate_dt"] = pandas.to_datetime(child_id[""], format="%Y-%m")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 child_id = pandas.read_csv (filepath)
# ----> 3 child_id["PersonBirthDate_dt"] = pandas.to_datetime(child_id["PersonBirthDate"], format="%Y-%m")
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...

# %%
child_id["PersonBirthDate_dt"] = pandas.to_datetime(child_id["PersonBirthDate"], format="%Y-%m-%d")
child_id["ExpectedPersonBirthDate_dt"] = pandas.to_datetime(child_id["ExpectedPersonBirthDate"], format="%Y-%m-%d")

child_id["PersonDeathDate_dt"] = pandas.to_datetime(child_id["PersonDeathDate"], format="%Y-%m-%d", errors="coerce")

child_id.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 child_id["PersonBirthDate_dt"] = pandas.to_datetime(child_id["PersonBirthDate"], format="%Y-%m-%d")
#       2 child_id["ExpectedPersonBirthDate_dt"] = pandas.to_datetime(child_id["ExpectedPersonBirthDate"], format="%Y-%m-%d")
#       4 child_id["PersonDeathDate_dt"] = pandas.to_datetime(child_id["PersonDeathDate"], format="%Y-%m-%d", errors="coerce")
#
# NameError: name 'pandas' is not defined
