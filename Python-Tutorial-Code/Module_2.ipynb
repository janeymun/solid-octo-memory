# %%
x=2
print (x)
# Out:
# 2

# %%
colours_1 = [10.00, "orange", 10, ["test1", "test2", "test3"]]
print (colours_1)
colours_1 [1]
colours_1[::2]
# Out:
# [10.0, 'orange', 10, ['test1', 'test2', 'test3']]
# [10.0, 10]

# %%
foods_1 = ["cheese", "ham"]
print (foods_1)
foods_1.append ("beef")
print (foods_1)
foods_1.append (["yogurt", "cabbage"])
print (foods_1)
foods_2 = ("triffle", "rice")
foods_1.append (foods_2)
print (foods_1)
foods_1.extend ("pasta")
print (foods_1)
# Out:
# ['cheese', 'ham']
# ['cheese', 'ham', 'beef']
# ['cheese', 'ham', 'beef', ['yogurt', 'cabbage']]
# ['cheese', 'ham', 'beef', ['yogurt', 'cabbage'], ('triffle', 'rice')]
# ['cheese', 'ham', 'beef', ['yogurt', 'cabbage'], ('triffle', 'rice'), 'p', 'a', 's', 't', 'a']

# %%
# make a dictionary of restaurants with keys being the name and values being the foods,
# make sure at least one value is a list of foods, and another is a dicitonary of days and foods
# use the keys, vlaues, and items methods to views those

dinner{"hickorys": "southern fried foods", "Hydes": "Pub Grub", "Mcdonalds": {Monday :["burger", "Fries"],"ROW": "Rubbish"}}
# Out:
#   Cell In[15], line 5
#     dinner{"hickorys": "southern fried foods", "Hydes": "Pub Grub", "Mcdonalds": {Monday :["burger", "Fries"],"ROW": "Rubbish"}}
#           ^
# SyntaxError: invalid syntax

# %%
dinner={"hickorys": "southern fried foods", "Hydes": "Pub Grub", "Mcdonalds": {"Monday" :["burger", "Fries"],"ROW": "Rubbish"}}
dinner
print ("hickorys" in dinner)
# Out:
# True

# %%
print hickorys in dinner
