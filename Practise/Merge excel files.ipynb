# %%
import glob
import pandas as pd

# %%
# specify folder dir
file_path = "C://downloads/file"
# get all .xlsx files in the folder
files = glob.glob (file_path + "/*.xlsx")

# read each file and store in list
list =[]
